# %%
import os, errno
import shutil

# %%
ROOT_DIR = "."
BATCH_SIZE = 8

# %%
dirs = [f for f in os.listdir(ROOT_DIR) if os.path.isdir(os.path.join(ROOT_DIR, f))]

# %%
# current_dir = os.path.join(ROOT_DIR, dirs[0])
for current_dir in dirs[:-1]:
#     print (current_dir)
    img_names = [f for f in os.listdir(current_dir) if os.path.isfile(os.path.join(current_dir, f))]
#     print (img_names)
    folder_count = 0
    while (img_names != []):
        folder_path = os.path.join(current_dir, str(folder_count))
        print (folder_path)
#         break
        try : 
            os.makedirs(folder_path)
        except OSError as e:
            if e.errno != errno.EEXIST:
                raise
            folder_count += 1
            continue
        img_names = [f for f in os.listdir(current_dir) if os.path.isfile(os.path.join(current_dir, f))]
        for i in range(BATCH_SIZE):
            try : 
                oldfilepath = os.path.join(current_dir,img_names[i])
                newfilepath = os.path.join(folder_path,img_names[i])
            except Exception as e : 
                print (e)
                break
            shutil.move(oldfilepath,newfilepath)

        folder_count += 1
        img_names = [f for f in os.listdir(current_dir) if os.path.isfile(os.path.join(current_dir, f))]
# Out:
# maths/0
# list index out of range
# mech/0
# mech/1
# mech/2
# mech/3
# list index out of range
# ee/0
# ee/1
# ee/2
# ee/3
# ee/4
# ee/5
# ee/6
# ee/7
# ee/8
# ee/9
# ee/10
# ee/11
# ee/12
# ee/13
# ee/14
# ee/15
# ee/16
# ee/17
# ee/18
# ee/19
# ee/20
# ee/21
# list index out of range
# dbeb/0
# dbeb/1
# dbeb/2
# dbeb/3
# list index out of range
# physics/0
# physics/1
# physics/2
# list index out of range
# civil/0
# civil/1
# civil/2
# civil/3
# civil/4
# civil/5
# civil/6
# civil/7
# civil/8
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-f36c951a6fd6> in <module>()
#       3 for current_dir in dirs[:-1]:
#       4 #     print (current_dir)
# ----> 5     img_names = [f for f in os.listdir(current_dir) if os.path.isfile(os.path.join(current_dir, f))]
#       6 #     print (img_names)
#       7     folder_count = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DP'

# %%
import collage_maker

for current_dir in dirs[:-1]:
#     print (current_dir)
    dir_names = [f for f in os.listdir(current_dir) if os.path.isdir(os.path.join(current_dir, f))]
#     print (img_names)
#     i = 0
    for folder in dir_names:
        folder_path = os.path.join(current_dir, folder)
        print (folder_path)
        args = {'folder':folder_path, 'width':850 , 'init_height':720, 'shuffle' : True , 'output' : os.path.join(current_dir,'out_'+folder+'.jpg')}
#         inside_path = os.path.join(folder_path)
        collage_maker.prepare(args)
#         i += 1
# Out:
# maths/0
# Making collage...
# Collage is ready!
# maths/2
# Making collage...
# Collage is ready!
# maths/3
# Making collage...
# Collage is ready!
# maths/1
# Making collage...
# Collage is ready!
# maths/4
# Making collage...
# Collage is ready!
# mech/0
# Making collage...
# Collage is ready!
# mech/2
# Making collage...
# Collage is ready!
# mech/3
# Making collage...
# Collage is ready!
# mech/1
# Making collage...
# Collage is ready!
# ee/6
# Making collage...
# Collage is ready!
# ee/21
# Making collage...
# Collage is ready!
# ee/0
# Making collage...
# Collage is ready!
# ee/2
# Making collage...
# Collage is ready!
# ee/7
# Making collage...
# Collage is ready!
# ee/8
# Making collage...
# Collage is ready!
# ee/3
# Making collage...
# Collage is ready!
# ee/10
# Making collage...
# Collage is ready!
# ee/1
# Making collage...
# Collage is ready!
# ee/5
# Making collage...
# Collage is ready!
# ee/4
# Making collage...
# Collage is ready!
# ee/16
# Making collage...
# Collage is ready!
# ee/12
# Making collage...
# Collage is ready!
# ee/11
# Making collage...
# Collage is ready!
# ee/19
# Making collage...
# Collage is ready!
# ee/13
# Making collage...
# Collage is ready!
# ee/20
# Making collage...
# Collage is ready!
# ee/18
# Making collage...
# Collage is ready!
# ee/9
# Making collage...
# Collage is ready!
# ee/14
# Making collage...
# Collage is ready!
# ee/15
# Making collage...
# Collage is ready!
# ee/17
# Making collage...
# Collage is ready!
# dbeb/0
# Making collage...
# Collage is ready!
# dbeb/2
# Making collage...
# Collage is ready!
# dbeb/3
# Making collage...
# Collage is ready!
# dbeb/1
# Making collage...
# Collage is ready!
# physics/0
# Making collage...
# Collage is ready!
# physics/2
# Making collage...
# Collage is ready!
# physics/1
# Making collage...
# Collage is ready!
# civil/6
# Making collage...
# Collage is ready!
# civil/0
# Making collage...
# Collage is ready!
# civil/2
# Making collage...
# Collage is ready!
# civil/7
# Making collage...
# Collage is ready!
# civil/8
# Making collage...
# Collage is ready!
# civil/3
# Making collage...
# Collage is ready!
# civil/1
# Making collage...
# Collage is ready!
# civil/5
# Making collage...
# Collage is ready!
# civil/4
# Making collage...
# Collage is ready!
# chemical/6
# Making collage...
# Collage is ready!
# chemical/0
# Making collage...
# Collage is ready!
# chemical/2
# Making collage...
# Collage is ready!
# chemical/7
# Making collage...
# Collage is ready!
# chemical/8
# Making collage...
# Collage is ready!
# chemical/3
# Making collage...
# Collage is ready!
# chemical/10
# Making collage...
# Collage is ready!
# chemical/1
# Making collage...
# Collage is ready!
# chemical/5
# Making collage...
# Collage is ready!
# chemical/4
# Making collage...
# Collage is ready!
# chemical/12
# Making collage...
# Collage is ready!
# chemical/11
# Making collage...
# Collage is ready!
# chemical/13
# Making collage...
# Collage is ready!
# chemical/9
# Making collage...
# Collage is ready!
# chemical/14
# Making collage...
# Collage is ready!
# cse/0
# Making collage...
# Collage is ready!
# cse/2
# Making collage...
# Collage is ready!
# cse/3
# Making collage...
# Collage is ready!
# cse/1
# Making collage...
# Collage is ready!
# cse/4
# Making collage...
# Collage is ready!

# %%
import subprocess

for current_dir in dirs[:-1]:
    print (current_dir)
    dir_names = [f for f in os.listdir(current_dir) if os.path.isdir(os.path.join(current_dir, f))]
#     print (dir_names)
    
#     for folder in dir_names:
#         folder_path = os.path.join(current_dir, folder)
#         print (folder_path)
        
#         bashCommand = 'convert "%s/out*.jpg" %s.pdf'%(folder_path, folder_path)
#         print(bashCommand)
#         process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
#         output, error = process.communicate()
#         print(output)
# Out:
# maths
# mech
# ee
# dbeb
# physics
# civil
# __pycache__
# chemical
# cse
